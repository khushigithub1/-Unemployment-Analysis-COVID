# %%
from src.data_loader import load_data
from src.analysis import yearly_avg
from src.visualization import plot_trend

# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

# %%
from src.visualization import *

plot_trend(df)
plot_statewise(df)
plot_area_comparison(df)
plot_yearly_trend(df)
plot_correlation(df)

# %% [markdown]
#  ## Key Insights from Analysis:
#
# 1. Unemployment rate peaked during the COVID-19 period (2020–2021).
# 2. Certain states consistently show higher unemployment rates compared to others.
# 3. Urban areas show higher fluctuation in unemployment than rural areas.
# 4. Labour participation rate is closely related to employment trends.
# 5. Gradual recovery is observed after the COVID peak period.

# %% [markdown]
# ## Conclusion
#
# This analysis of unemployment in India provides clear insights into how the labour market was affected during the COVID-19 period. The study shows that the unemployment rate increased significantly during 2020, indicating the severe impact of lockdowns and economic slowdown on job availability.
#
# State-wise analysis highlights that unemployment levels vary across different regions, reflecting regional economic disparities. Urban and rural comparisons also show differences in unemployment patterns, suggesting uneven recovery across sectors.
#
# The labour participation rate and employment levels are closely related to unemployment trends, indicating that changes in workforce participation directly influence unemployment conditions.
#
# Overall, the analysis demonstrates that COVID-19 had a major negative impact on employment in India, but gradual recovery trends can also be observed in the post-pandemic period. These insights can help policymakers understand labour market behavior and design better employment recovery strategies.
